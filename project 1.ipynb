# %%
import random


print('''It is Rock,paper,scissor game.
Choose anything among Rock(1) or paper(2) or scissor(3)''')

while True:
    choice = int(input("\nYour turn: "))
    while choice > 3 or choice < 1:
        choice = int(input("please enter valid input: "))


    if choice == 1:
        choice_name = "Rock"
    elif choice == 2:
        choice_name = "Paper"
    elif choice == 3:
        choice_name = "scissor"




    print("Your choice is : ",choice_name)
    print("\nNow its computer turn...!")



    comp_choice = random.randint(1,3)

    while comp_choice == choice:
        comp_choice = random.randint(1,3)

    if comp_choice == 1:
        comp_choice_name = "Rock"
    elif comp_choice == 2:
        comp_choice_name = "Paper"
    elif comp_choice == 3:
        comp_choice_name = "scissor"

    print("Computer choice is: ",comp_choice_name)
    print()


    print(choice_name+ " V/s " + comp_choice_name)
    print()

    if ((choice == 1 and comp_choice ==2) or 
        (choice == 2 and comp_choice ==1) ):
        print("Paper Wins!")
        result = "Paper"

    elif ((choice ==1 and comp_choice ==3) or 
        (choice == 3 and comp_choice ==1) ):
        print("Rock Wins!")
        result = "Rock"

    elif ((choice == 3 and comp_choice ==2) or 
        (choice == 2 and comp_choice ==3) ):
        print("Scissor Wins!")
        result = "Scissor"


    if result == choice_name:
        print("\n\n!---User Wins---!")
    else:
        print("!---Computer Wins---!")

    print("\n\n Wanna play this game? (Y/N) ")
    ans = input().upper()

    if ans == "N":
        break
        

    
    
print("\n Thanks for playing!")
# Out:
# It is Rock,paper,scissor game.
# Choose anything among Rock(1) or paper(2) or scissor(3)
#
# Your turn: 1
# Your choice is :  Rock
#
# Now its computer turn...!
# Computer choice is:  scissor
#
# Rock V/s scissor
#
# Rock Wins!
#
#
# !---User Wins---!
#
#
#  Wanna play this game? (Y/N)
# y
#
# Your turn: 2
# Your choice is :  Paper
#
# Now its computer turn...!
# Computer choice is:  scissor
#
# Paper V/s scissor
#
# Scissor Wins!
# !---Computer Wins---!
#
#
#  Wanna play this game? (Y/N)
# y
#
# Your turn: 3
# Your choice is :  scissor
#
# Now its computer turn...!
# Computer choice is:  Paper
#
# scissor V/s Paper
#
# Scissor Wins!
# !---Computer Wins---!
#
#
#  Wanna play this game? (Y/N)
# n
#
#  Thanks for playing!
